# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a serious of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Check the number of rows and columns.

# %%
# Answer: 
movies.shape
# Out:
# (979, 6)

# %%
movies.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %% [markdown]
# Checking column headers as well.

# %% [markdown]
# #### Check the data type of each column.

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# #### Calculate the average movie duration.

# %%
# Answer:
movies.duration.mean()
# Out:
# 120.97957099080695

# %%
movies.mean()
# Out:
# star_rating      7.889785
# duration       120.979571
# dtype: float64

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
# Answer:
movies.sort_values('duration').head(1)
# Out:
#      star_rating   title content_rating  genre  duration  \
# 389          8.0  Freaks        UNRATED  Drama        64
#
#                                            actors_list
# 389  [u'Wallace Ford', u'Leila Hyams', u'Olga Bacla...

# %%
movies.sort_values('duration').tail(1)
# Out:
#      star_rating   title content_rating  genre  duration  \
# 476          7.8  Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
movies.sort_values('duration')
# Out:
#      star_rating                                          title  \
# 389          8.0                                         Freaks
# 338          8.0                            Battleship Potemkin
# 258          8.1                    The Cabinet of Dr. Caligari
# 293          8.1                                      Duck Soup
# 88           8.4                                        The Kid
# 742          7.6                                      Following
# 351          8.0                                   Frankenstein
# 938          7.4                            Alice in Wonderland
# 405          7.9                      The Bride of Frankenstein
# 303          8.0                 The Nightmare Before Christmas
# 713          7.6                                The Jungle Book
# 864          7.5                                          [Rec]
# 489          7.8                     The Triplets of Belleville
# 535          7.8                                          Zelig
# ...

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
# Answer:
movies.loc[:, 'duration'].plot(kind = 'hist', bins=40);

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
# Answer:
movies.loc[:, 'duration'].plot(kind = 'box', );

# %% [markdown]
# ## Intermediate level

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
movies.content_rating.value_counts()
# Out:
# R          460
# PG-13      189
# UNRATED    163
# PG         123
# G           32
# NC-17       12
# Name: content_rating, dtype: int64

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
# Answer:
movies.content_rating.value_counts().plot(kind = 'bar', 
                                          title = 'Top Movies by Rating', color='orange');
plt.xlabel('Rating')
plt.ylabel('Movies')
# Out:
# Text(0,0.5,'Movies')

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
# Answer:

# %%
movies.sort_values('content_rating')
# Out:
#      star_rating                                title content_rating  \
# 204          8.1                              Ben-Hur              G
# 625          7.7                                Ponyo              G
# 192          8.2                         Finding Nemo              G
# 461          7.9              Kiki's Delivery Service              G
# 497          7.8  Willy Wonka & the Chocolate Factory              G
# 498          7.8                             Fantasia              G
# 766          7.6                   The Little Mermaid              G
# 294          8.1                 Beauty and the Beast              G
# 55           8.5                        The Lion King              G
# 759          7.6                           Robin Hood              G
# 938          7.4                  Alice in Wonderland              G
# 674          7.7         The Secret World of Arrietty              G
# 168          8.2                  Hachi: A Dog's Tale              G
# ...

# %%
movies.content_rating.replace(['NOT RATED', 'APPROVED', 'PASSED', 'GP'], 
                                'UNRATED', inplace = True)
movies.content_rating.unique()
# Out:
# array(['R', 'PG-13', 'UNRATED', 'PG', 'G', 'NC-17'], dtype=object)

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:

# %%
movies.content_rating.replace(['X', 'TV-MA'],'NC-17', inplace = True)

# %%
movies.content_rating.unique()
# Out:
# array(['R', 'PG-13', 'UNRATED', 'PG', 'G', 'NC-17'], dtype=object)

# %% [markdown]
# Check to see if NC-17 was added.

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
# Answer:

# %%
movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
movies[movies.content_rating.isnull()]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:

# %%
movies.content_rating.fillna('UNRATED', inplace=True)
movies.loc[:, 'content_rating']
# Out:
# 0            R
# 1            R
# 2            R
# 3        PG-13
# 4            R
# 5      UNRATED
# 6      UNRATED
# 7        PG-13
# 8            R
# 9            R
# 10       PG-13
# 11       PG-13
# 12          PG
# 13       PG-13
# 14       PG-13
# 15       PG-13
# 16           R
# 17     UNRATED
# 18           R
# 19          PG
# 20           R
# 21           R
# 22     UNRATED
# 23           R
# 24           R
# 25       PG-13
# 26       PG-13
# 27           R
# 28           R
# 29     UNRATED
#         ...
# 949         PG
# 950          R
# 951          R
# 952          R
# 953         PG
# 954      PG-13
# 955          R
# 956         PG
# 957          R
# 958      PG-13
# 959          R
# 960      PG-13
# 961          R
# 962         PG
# 963          R
# 964      PG-13
# 965      PG-13
# 966      PG-13
# 967          R
# 968          R
# 969          R
# 970          R
# 971          R
# 972      NC-17
# 973      PG-13
# 974         PG
# 975         PG
# 976      PG-13
# ...

# %%
movies[movies.content_rating.isnull()]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %% [markdown]
# Test to check if there is null

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
# Answer:
movies[movies.duration > 120].mean()
# Out:
# star_rating      7.953670
# duration       143.385321
# dtype: float64

# %%
movies[movies.duration < 120].mean()
# Out:
# star_rating      7.838667
# duration       102.405714
# dtype: float64

# %%
#longer movies had a slightly higher rating

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
# Answer:

# %%
movies.plot(kind = 'scatter', x='duration', y='star_rating', alpha=0.3, color='purple',
           figsize=(14,7));

# %%
#Answer: Average duration is around 100-150 and average star rating is around 7.50-8.50.
#No direct correlation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(movies);

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
movies.groupby(['duration', 'genre']).mean()
# Out:
#                     star_rating
# duration genre
# 64       Drama         8.000000
# 66       History       8.000000
# 67       Crime         8.100000
# 68       Comedy        8.250000
# 69       Mystery       7.600000
# 70       Horror        8.000000
# 75       Animation     7.400000
#          Horror        7.900000
# 76       Animation     8.000000
# 78       Animation     7.700000
#          Horror        7.500000
# 79       Comedy        7.800000
# 80       Action        7.800000
#          Animation     7.500000
#          Comedy        7.700000
#          Crime         8.000000
#          Drama         8.100000
#          Horror        7.800000
# 81       Animation     7.900000
#          Comedy        7.600000
#          Horror        8.000000
# 82       Comedy        7.850000
# 83       Animation     7.733333
#          Drama         8.200000
#          Horror        7.500000
# 84       Animation     8.100000
#          Comedy        7.800000
# ...

# %% [markdown]
# Scratch above

# %%
# Answer - Below:

# %%
movies.groupby('genre').duration.mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer:

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.boxplot(column='duration', by='content_rating', figsize=(10,5));
# Out:
# /Users/ginaadduci/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
movies.plot(kind='hist', x='content_rating', y='duration', bins=30);

# %% [markdown]
# #### Determine the top rated movie (by star rating) for each genre.

# %%
# Answer:

# %%
movies.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %% [markdown]
# Movies within genre

# %%
movie_genres = ['Drama', 'Comedy', 'Action', 'Crime', 'Biography', 'Adventure'
             'Animation', 'Horror', 'Mystery', 'Wester', 'Sci-Fi', 'Thriller', 'Film-Noir'
             'Family', 'Fantasy', 'History']

# %%
movies[movies.genre.isin(movie_genres)].groupby('genre').star_rating.mean()
# Out:
# genre
# Action       7.884559
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Fantasy      7.700000
# History      8.000000
# Horror       7.806897
# Mystery      7.975000
# Sci-Fi       7.920000
# Thriller     7.680000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
duplicated = movies[movies.title.duplicated()].title
movies[movies.title.isin(duplicated)]
# Out:
#      star_rating                            title content_rating      genre  \
# 466          7.9  The Girl with the Dragon Tattoo              R      Crime
# 482          7.8  The Girl with the Dragon Tattoo              R      Crime
# 662          7.7                        True Grit          PG-13  Adventure
# 678          7.7                   Les Miserables          PG-13      Drama
# 703          7.6                          Dracula        UNRATED     Horror
# 905          7.5                          Dracula              R     Horror
# 924          7.5                   Les Miserables          PG-13      Crime
# 936          7.4                        True Grit        UNRATED  Adventure
#
#      duration                                        actors_list
# 466       158  [u'Daniel Craig', u'Rooney Mara', u'Christophe...
# 482       152  [u'Michael Nyqvist', u'Noomi Rapace', u'Ewa Fr...
# 662       110  [u'Jeff Bridges', u'Matt Damon', u'Hailee Stei...
# ...

# %%
duplicated.sort_values()
# Out:
# 905                            Dracula
# 924                     Les Miserables
# 482    The Girl with the Dragon Tattoo
# 936                          True Grit
# Name: title, dtype: object

# %% [markdown]
# # Answer: Dracula, Les Miserables, The Girl with the Dragon Tatoo, True Grit

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
top = ['Drama', 'Comedy', 'Action', 'Crime', 'Biography', 'Adventure'
             'Animation', 'Horror', 'Mystery']
movies.groupby('genre').star_rating.sum()
# Out:
# genre
# Action       1072.3
# Adventure     595.0
# Animation     490.7
# Biography     605.4
# Comedy       1220.3
# Crime         981.7
# Drama        2196.9
# Family         15.7
# Fantasy         7.7
# Film-Noir      24.1
# History         8.0
# Horror        226.4
# Mystery       127.6
# Sci-Fi         39.6
# Thriller       38.4
# Western        74.3
# Name: star_rating, dtype: float64

# %% [markdown]
# Defined Top Movies and found the sum of star rating by genre

# %%
movies[movies.genre.isin(top)].groupby('genre').star_rating.mean()
# Out:
# genre
# Action       7.884559
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
# Answer:

# %%
movies.groupby('genre').star_rating.mean()[movies.genre.value_counts()>10]
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:

# %%
movies.groupby('genre').star_rating.mean()
[movies.genre.value_counts()>10]
# Out:
# [Drama         True
#  Comedy        True
#  Action        True
#  Crime         True
#  Biography     True
#  Adventure     True
#  Animation     True
#  Horror        True
#  Mystery       True
#  Western      False
#  Sci-Fi       False
#  Thriller     False
#  Film-Noir    False
#  Family       False
#  Fantasy      False
#  History      False
#  Name: genre, dtype: bool]

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:

# %%
genre_rate = movies.groupby('genre').star_rating.agg(['count', 'mean'])
genre_rate
# Out:
#            count      mean
# genre
# Action       136  7.884559
# Adventure     75  7.933333
# Animation     62  7.914516
# Biography     77  7.862338
# Comedy       156  7.822436
# Crime        124  7.916935
# Drama        278  7.902518
# Family         2  7.850000
# Fantasy        1  7.700000
# Film-Noir      3  8.033333
# History        1  8.000000
# Horror        29  7.806897
# Mystery       16  7.975000
# Sci-Fi         5  7.920000
# Thriller       5  7.680000
# Western        9  8.255556

# %%
genre_rate[genre_rate['count'] > 10]
# Out:
#            count      mean
# genre
# Action       136  7.884559
# Adventure     75  7.933333
# Animation     62  7.914516
# Biography     77  7.862338
# Comedy       156  7.822436
# Crime        124  7.916935
# Drama        278  7.902518
# Horror        29  7.806897
# Mystery       16  7.975000

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Figure out something "interesting" using the actors data!

# %%
movies.groupby('actors_list').star_rating.sum().sort_values()
# Out:
# actors_list
# [u'Ralph Fiennes', u'Juliette Binoche', u'Willem Dafoe']                     7.4
# [u'Ryan Gosling', u'Michelle Williams', u'John Doman']                       7.4
# [u'Gerard Butler', u'Jamie Foxx', u'Leslie Bibb']                            7.4
# [u'Philip Seymour Hoffman', u'Clifton Collins Jr.', u'Catherine Keener']     7.4
# [u'Jack Nicholson', u'Morgan Freeman', u'Sean Hayes']                        7.4
# [u'Steve Carell', u'Toni Collette', u'Allison Janney']                       7.4
# [u'Steve Carell', u'Ryan Gosling', u'Julianne Moore']                        7.4
# [u'JoBeth Williams', u"Heather O'Rourke", u'Craig T. Nelson']                7.4
# [u'Patrick Stewart', u'Hugh Jackman', u'Ian McKellen']                       7.4
# [u'Anne Parillaud', u'Marc Duret', u'Patrick Fontana']                       7.4
# [u'Morgan Freeman', u'Jessica Tandy', u'Dan Aykroyd']                        7.4
# ...
